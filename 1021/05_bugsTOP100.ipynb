# %%
import requests
from bs4 import BeautifulSoup

# %%
import datetime
now = datetime.datetime.now()
print(now)
# Out:
# 2020-10-21 20:14:35.957902

# %%
from datetime import datetime
now = datetime.now()
print(now)
# Out:
# 2020-10-21 20:14:35.964901

# %%
from datetime import datetime as dt
now = dt.now()
print(now)
# Out:
# 2020-10-21 20:14:35.970900

# %%
print(dt.now()) # 컴퓨터 시스템으 날짜와 시간을 얻어온다.
print(dt.now().year)
print(dt.now().month)
print(dt.now().day)
print(dt.now().hour)
print(dt.now().minute)
print(dt.now().second)
print(dt.now().microsecond)
print(dt.now().microsecond // 1000)
week = ['월요일', '화요일', '수요일', '목요일', '금요일', '토요일', '일요일']
print(dt.now().weekday()) # 요일을 숫자로 리턴한다. 월요일(0), 화요일(1), 수요일(2), 목요일(3), 금요일(4), 토요일(5), 일요일(6)
print(week[dt.now().weekday()])
# Out:
# 2020-10-21 20:14:35.980901
# 2020
# 10
# 21
# 20
# 14
# 35
# 981916
# 981
# 2
# 수요일

# %%
targetSite = 'https://music.bugs.co.kr/chart'

# %%
request = requests.get(targetSite)
# print(request)
html = request.text
# print(html)
soup = BeautifulSoup(html, 'html.parser')
# print(soup)

# %%
# 노래 제목 크롤링
titles = soup.findAll('p', {'class': 'title'})
# print(titles)
# print(len(titles))
for title in titles:
    # print(title.text.strip())
    # print(title.text.split('\n')[1])
    print(title.text.strip().split('\n')[0])
# Out:
# 놓아줘 (with 태연)
# 딩가딩가 (Dingga)
# DON'T TOUCH ME
# Lovesick Girls
# 힘든 건 사랑이 아니다
# Tip Toe (with 이하이)
# Dynamite
# ALIEN
# Savage Love (Laxed - Siren Beat) (BTS Remix)
# 사랑 못해, 남들 쉽게 다 하는 거
# 춤 (with 이소라)
# Step By Step (with 윤미래)
# She Said (with BIBI)
# Bad Boy
# 소확행
# Fake
# Pretty Savage
# 취기를 빌려 (취향저격 그녀 X 산들)
# Bet You Wanna (Feat. Cardi B)
# 우리 사랑한 동안
# 잠이 들어야 (Feat. 헤이즈)
# 오래된 노래
# Make A Wish (Birthday Song)
# 밤하늘의 저 별처럼
# 에잇(Prod.&Feat. SUGA of BTS)
# Blueming
# When We Disco (Duet with 선미)
# Ice Cream (with Selena Gomez)
# 눈누난나 (NUNU NANA)
# Dolphin
# 밤새 (취향저격 그녀 X 카더가든)
# 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
# Not Shy
# How You Like That
# 마리아 (Maria)
# HOME;RUN
# 사랑하고 싶지 않아 (바른연애 길잡이 X XIA (준수))
# 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# Love To Hate Me
# 홀로
# Holy (feat. Chance The Rapper)
# 숲의 아이 (Bon voyage)
# 살짝 설렜어 (Nonstop)
# 그리워하면 그댈 만날까봐
# Dance Monkey
# 덤디덤디 (DUMDi DUMDi)
# Love poem
# Crazy Over You
# 이미 널 잊었어
# 밤편지
# 12:45 (Stripped)
# 모든 날, 모든 순간 (Every day, Every Moment)
# Downtown Baby
# 거짓말이라도 해서 널 보고싶어
# 아로하
# Memories
# Maniac
# 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# 다시 여기 바닷가
# 내일은 고백할게
# 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
# 꽃길을 걸어요
# Tight
# METEOR
# WANNA BE MYSELF
# 테스형!
# 늦은 밤 너의 집 앞 골목길에서
# 2002
# 내 마음을 누르는 일 (Daystar)
# Square (2017)
# Psycho
# 어떻게 지내 (Prod. By VAN.C)
# 사계 (Four Seasons)
# Juice
# 영화처럼
# 행복해
# Day & Night
# Watermelon Sugar
# 보라빛 밤 (pporappippam)
# 미래
# LALALILALA
# 안녕
# 오래된 노래
# Cloud (Feat. 초아)
# 가을 타나 봐
# 사랑하게 될 줄 알았어
# 축하해
# 마음을 드려요
# You Never Know
# Don't Start Now
# 우리서로사랑하지는말자
# 주저하는 연인들을 위해
# 이제 나만 믿어요
# Into the I-LAND
# 사랑은 지날수록 더욱 선명하게 남아
# Melody
# 나의 시간은
# 좋은 사람 있으면 소개시켜줘
# 데이지
# Paris In The Rain

# %%
# 아트스트 크롤링
artists = soup.findAll('p', {'class': 'artist'})
# print(artists)
# print(len(artists))
for artist in artists:
    # print(artist.text.strip())
    # print(artist.text.split('\n'))
    print(artist.text.strip().split('\n')[0])
# Out:
# Crush
# 마마무(Mamamoo)
# 환불원정대
# BLACKPINK
# 임창정
# Crush
# 방탄소년단
# 이수현
# Jawsh 685
# 먼데이 키즈(Monday Kiz)
# Crush
# Crush
# Crush
# 청하
# 임창정
# Lauv(라우브)
# BLACKPINK
# 산들
# BLACKPINK
# 에일리(AILEE)
# 로꼬
# 스탠딩 에그(Standing Egg)
# NCT U
# 헤이즈(Heize)
# 아이유(IU)
# 아이유(IU)
# 박진영
# BLACKPINK
# 제시(Jessi)
# 오마이걸(OH MY GIRL)
# 카더가든
# 규현 (KYUHYUN)
# ITZY (있지)
# BLACKPINK
# 화사(Hwa Sa)
# 세븐틴(Seventeen)
# XIA(준수)
# 장범준
# BLACKPINK
# 이하이
# Justin Bieber(저스틴 비버)
# 유아 (오마이걸)
# 오마이걸(OH MY GIRL)
# 김나영
# Tones And I
# (여자)아이들
# 아이유(IU)
# BLACKPINK
# 임창정
# 아이유(IU)
# Etham
# 폴킴(Paul Kim)
# 블루(BLOO)
# 백지영
# 조정석
# Maroon 5(마룬 파이브)
# Conan Gray
# AKMU (악동뮤지션)
# 싹쓰리 (유두래곤, 린다G, 비룡)
# 태연 (TAEYEON)
# 방탄소년단
# 임창정
# 10CM
# 창모(CHANGMO)
# 마마무(Mamamoo)
# 나훈아
# 노을
# Anne-Marie(앤 마리)
# 규현 (KYUHYUN)
# 백예린
# Red Velvet (레드벨벳)
# 오반
# 태연 (TAEYEON)
# Lizzo
# B1A4
# 송하예
# 정승환
# Harry Styles(해리 스타일스)
# 선미
# Red Velvet (레드벨벳)
# 에이프릴(APRIL)
# 폴킴(Paul Kim)
# 임영웅
# 프라이머리
# 바이브
# 전미도
# 오반
# 아이유(IU)
# BLACKPINK
# Dua Lipa(두아 리파)
# 기리보이
# 잔나비
# 임영웅
# 아이유(IU)
# 전상근
# 윤딴딴
# 백현(BAEKHYUN)
# 조이 (JOY)
# 펜타곤
# Lauv(라우브)

# %%
print(dt.now())
for i in range(len(titles)):
    artist = artists[i].text.strip().split('\n')[0]
    title = titles[i].text.strip().split('\n')[0]
    print('{0:3d}위 {1} - {2}'.format(i + 1, artist, title))
# Out:
# 2020-10-21 20:20:06.560221
#   1위 Crush - 놓아줘 (with 태연)
#   2위 마마무(Mamamoo) - 딩가딩가 (Dingga)
#   3위 환불원정대 - DON'T TOUCH ME
#   4위 BLACKPINK - Lovesick Girls
#   5위 임창정 - 힘든 건 사랑이 아니다
#   6위 Crush - Tip Toe (with 이하이)
#   7위 방탄소년단 - Dynamite
#   8위 이수현 - ALIEN
#   9위 Jawsh 685 - Savage Love (Laxed - Siren Beat) (BTS Remix)
#  10위 먼데이 키즈(Monday Kiz) - 사랑 못해, 남들 쉽게 다 하는 거
#  11위 Crush - 춤 (with 이소라)
#  12위 Crush - Step By Step (with 윤미래)
#  13위 Crush - She Said (with BIBI)
#  14위 청하 - Bad Boy
#  15위 임창정 - 소확행
#  16위 Lauv(라우브) - Fake
#  17위 BLACKPINK - Pretty Savage
#  18위 산들 - 취기를 빌려 (취향저격 그녀 X 산들)
#  19위 BLACKPINK - Bet You Wanna (Feat. Cardi B)
#  20위 에일리(AILEE) - 우리 사랑한 동안
#  21위 로꼬 - 잠이 들어야 (Feat. 헤이즈)
#  22위 스탠딩 에그(Standing Egg) - 오래된 노래
#  23위 NCT U - Make A Wish (Birthday Song)
#  24위 헤이즈(Heize) - 밤하늘의 저 별처럼
#  25위 아이유(IU) - 에잇(Prod.&Feat. SUGA of BTS)
#  26위 아이유(IU) - Blueming
#  27위 박진영 - When We Disco (Duet with 선미)
#  28위 BLACKPINK - Ice Cream (with Selena Gomez)
#  29위 제시(Jessi) - 눈누난나 (NUNU NANA)
#  30위 오마이걸(OH MY GIRL) - Dolphin
#  31위 카더가든 - 밤새 (취향저격 그녀 X 카더가든)
#  32위 규현 (KYUHYUN) - 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
#  33위 ITZY (있지) - Not Shy
#  34위 BLACKPINK - How You Like That
#  35위 화사(Hwa Sa) - 마리아 (Maria)
#  36위 세븐틴(Seventeen) - HOME;RUN
#  37위 XIA(준수) - 사랑하고 싶지 않아 (바른연애 길잡이 X XIA (준수))
#  38위 장범준 - 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
#  39위 BLACKPINK - Love To Hate Me
#  40위 이하이 - 홀로
#  41위 Justin Bieber(저스틴 비버) - Holy (feat. Chance The Rapper)
#  42위 유아 (오마이걸) - 숲의 아이 (Bon voyage)
#  43위 오마이걸(OH MY GIRL) - 살짝 설렜어 (Nonstop)
#  44위 김나영 - 그리워하면 그댈 만날까봐
#  45위 Tones And I - Dance Monkey
#  46위 (여자)아이들 - 덤디덤디 (DUMDi DUMDi)
#  47위 아이유(IU) - Love poem
#  48위 BLACKPINK - Crazy Over You
#  49위 임창정 - 이미 널 잊었어
#  50위 아이유(IU) - 밤편지
#  51위 Etham - 12:45 (Stripped)
#  52위 폴킴(Paul Kim) - 모든 날, 모든 순간 (Every day, Every Moment)
#  53위 블루(BLOO) - Downtown Baby
#  54위 백지영 - 거짓말이라도 해서 널 보고싶어
#  55위 조정석 - 아로하
#  56위 Maroon 5(마룬 파이브) - Memories
#  57위 Conan Gray - Maniac
#  58위 AKMU (악동뮤지션) - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
#  59위 싹쓰리 (유두래곤, 린다G, 비룡) - 다시 여기 바닷가
#  60위 태연 (TAEYEON) - 내일은 고백할게
#  61위 방탄소년단 - 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
#  62위 임창정 - 꽃길을 걸어요
#  63위 10CM - Tight
#  64위 창모(CHANGMO) - METEOR
#  65위 마마무(Mamamoo) - WANNA BE MYSELF
#  66위 나훈아 - 테스형!
#  67위 노을 - 늦은 밤 너의 집 앞 골목길에서
#  68위 Anne-Marie(앤 마리) - 2002
#  69위 규현 (KYUHYUN) - 내 마음을 누르는 일 (Daystar)
#  70위 백예린 - Square (2017)
#  71위 Red Velvet (레드벨벳) - Psycho
#  72위 오반 - 어떻게 지내 (Prod. By VAN.C)
#  73위 태연 (TAEYEON) - 사계 (Four Seasons)
#  74위 Lizzo - Juice
#  75위 B1A4 - 영화처럼
#  76위 송하예 - 행복해
#  77위 정승환 - Day & Night
#  78위 Harry Styles(해리 스타일스) - Watermelon Sugar
#  79위 선미 - 보라빛 밤 (pporappippam)
#  80위 Red Velvet (레드벨벳) - 미래
#  81위 에이프릴(APRIL) - LALALILALA
#  82위 폴킴(Paul Kim) - 안녕
#  83위 임영웅 - 오래된 노래
#  84위 프라이머리 - Cloud (Feat. 초아)
#  85위 바이브 - 가을 타나 봐
#  86위 전미도 - 사랑하게 될 줄 알았어
#  87위 오반 - 축하해
#  88위 아이유(IU) - 마음을 드려요
#  89위 BLACKPINK - You Never Know
#  90위 Dua Lipa(두아 리파) - Don't Start Now
#  91위 기리보이 - 우리서로사랑하지는말자
#  92위 잔나비 - 주저하는 연인들을 위해
#  93위 임영웅 - 이제 나만 믿어요
#  94위 아이유(IU) - Into the I-LAND
#  95위 전상근 - 사랑은 지날수록 더욱 선명하게 남아
#  96위 윤딴딴 - Melody
#  97위 백현(BAEKHYUN) - 나의 시간은
#  98위 조이 (JOY) - 좋은 사람 있으면 소개시켜줘
#  99위 펜타곤 - 데이지
# 100위 Lauv(라우브) - Paris In The Rain

# %%
# 크롤링한 결과를 텍스트 파일에 저장한다.
# 크롤링한 데이터를 텍스트 파일에 저장하려는 경우 아래와 같이 파일을 열면 한글 인코딩 문제로 UnicodeEncodeError가 발생될 수
# 있다.
file = open('bugsTOP100.txt', 'w')
# UnicodeEncodeError: 'cp949' codec can't encode character '\xf1' in position 29: illegal multibyte sequence 에러가 발생되면
# 아래와 같이 파일을 open 시키면 된다.
# file = open('bugsTOP100.txt', 'w', -1, 'UTF-8')
file.write('{} 현재 Bugs 뮤직 실시간 TOP 100\n'.format(dt.now()))

for i in range(100):
    artist = artists[i].text.strip().split('\n')[0]
    title = titles[i].text.strip().split('\n')[0]
    data = '{0:3d}위 {1} - {2}'.format(i + 1, artist, title)
    file.write(data + '\n')
    
file.close()
print('bugsTOP100.txt 파일로 쓰기 완료')
# Out:
# bugsTOP100.txt 파일로 쓰기 완료

# %%
# 텍스트 파일에 저장된 크롤링 데이터를 읽어서 화면에 출력한다.
try:
    file = open('bugsTOP100.txt', 'r')
    # readlines() 메소드는 텍스트 파일 내용 전체를 한꺼번에 읽어 list로 변환한다.
    lines = file.readlines()
    # print(type(lines))
    for line in lines:
        # print(line, end = '') # 출력하고 줄을 바꾸지 않는다.
        print(line.strip())
    file.close()
    print('bugsTOP100.txt 파일에서 읽기 완료')
except:
    print('디스크에 읽을 파일이 없습니다.')
# Out:
# 2020-10-21 20:30:39.345183 현재 Bugs 뮤직 실시간 TOP 100
# 1위 Crush - 놓아줘 (with 태연)
# 2위 마마무(Mamamoo) - 딩가딩가 (Dingga)
# 3위 환불원정대 - DON'T TOUCH ME
# 4위 BLACKPINK - Lovesick Girls
# 5위 임창정 - 힘든 건 사랑이 아니다
# 6위 Crush - Tip Toe (with 이하이)
# 7위 방탄소년단 - Dynamite
# 8위 이수현 - ALIEN
# 9위 Jawsh 685 - Savage Love (Laxed - Siren Beat) (BTS Remix)
# 10위 먼데이 키즈(Monday Kiz) - 사랑 못해, 남들 쉽게 다 하는 거
# 11위 Crush - 춤 (with 이소라)
# 12위 Crush - Step By Step (with 윤미래)
# 13위 Crush - She Said (with BIBI)
# 14위 청하 - Bad Boy
# 15위 임창정 - 소확행
# 16위 Lauv(라우브) - Fake
# 17위 BLACKPINK - Pretty Savage
# 18위 산들 - 취기를 빌려 (취향저격 그녀 X 산들)
# 19위 BLACKPINK - Bet You Wanna (Feat. Cardi B)
# 20위 에일리(AILEE) - 우리 사랑한 동안
# 21위 로꼬 - 잠이 들어야 (Feat. 헤이즈)
# 22위 스탠딩 에그(Standing Egg) - 오래된 노래
# 23위 NCT U - Make A Wish (Birthday Song)
# 24위 헤이즈(Heize) - 밤하늘의 저 별처럼
# 25위 아이유(IU) - 에잇(Prod.&Feat. SUGA of BTS)
# 26위 아이유(IU) - Blueming
# 27위 박진영 - When We Disco (Duet with 선미)
# 28위 BLACKPINK - Ice Cream (with Selena Gomez)
# 29위 제시(Jessi) - 눈누난나 (NUNU NANA)
# 30위 오마이걸(OH MY GIRL) - Dolphin
# 31위 카더가든 - 밤새 (취향저격 그녀 X 카더가든)
# 32위 규현 (KYUHYUN) - 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
# 33위 ITZY (있지) - Not Shy
# 34위 BLACKPINK - How You Like That
# 35위 화사(Hwa Sa) - 마리아 (Maria)
# 36위 세븐틴(Seventeen) - HOME;RUN
# 37위 XIA(준수) - 사랑하고 싶지 않아 (바른연애 길잡이 X XIA (준수))
# 38위 장범준 - 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# 39위 BLACKPINK - Love To Hate Me
# 40위 이하이 - 홀로
# 41위 Justin Bieber(저스틴 비버) - Holy (feat. Chance The Rapper)
# 42위 유아 (오마이걸) - 숲의 아이 (Bon voyage)
# 43위 오마이걸(OH MY GIRL) - 살짝 설렜어 (Nonstop)
# 44위 김나영 - 그리워하면 그댈 만날까봐
# 45위 Tones And I - Dance Monkey
# 46위 (여자)아이들 - 덤디덤디 (DUMDi DUMDi)
# 47위 아이유(IU) - Love poem
# 48위 BLACKPINK - Crazy Over You
# 49위 임창정 - 이미 널 잊었어
# 50위 아이유(IU) - 밤편지
# 51위 Etham - 12:45 (Stripped)
# 52위 폴킴(Paul Kim) - 모든 날, 모든 순간 (Every day, Every Moment)
# 53위 블루(BLOO) - Downtown Baby
# 54위 백지영 - 거짓말이라도 해서 널 보고싶어
# 55위 조정석 - 아로하
# 56위 Maroon 5(마룬 파이브) - Memories
# 57위 Conan Gray - Maniac
# 58위 AKMU (악동뮤지션) - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# 59위 싹쓰리 (유두래곤, 린다G, 비룡) - 다시 여기 바닷가
# 60위 태연 (TAEYEON) - 내일은 고백할게
# 61위 방탄소년단 - 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
# 62위 임창정 - 꽃길을 걸어요
# 63위 10CM - Tight
# 64위 창모(CHANGMO) - METEOR
# 65위 마마무(Mamamoo) - WANNA BE MYSELF
# 66위 나훈아 - 테스형!
# 67위 노을 - 늦은 밤 너의 집 앞 골목길에서
# 68위 Anne-Marie(앤 마리) - 2002
# 69위 규현 (KYUHYUN) - 내 마음을 누르는 일 (Daystar)
# 70위 백예린 - Square (2017)
# 71위 Red Velvet (레드벨벳) - Psycho
# 72위 오반 - 어떻게 지내 (Prod. By VAN.C)
# 73위 태연 (TAEYEON) - 사계 (Four Seasons)
# 74위 Lizzo - Juice
# 75위 B1A4 - 영화처럼
# 76위 송하예 - 행복해
# 77위 정승환 - Day & Night
# 78위 Harry Styles(해리 스타일스) - Watermelon Sugar
# 79위 선미 - 보라빛 밤 (pporappippam)
# 80위 Red Velvet (레드벨벳) - 미래
# 81위 에이프릴(APRIL) - LALALILALA
# 82위 폴킴(Paul Kim) - 안녕
# 83위 임영웅 - 오래된 노래
# 84위 프라이머리 - Cloud (Feat. 초아)
# 85위 바이브 - 가을 타나 봐
# 86위 전미도 - 사랑하게 될 줄 알았어
# 87위 오반 - 축하해
# 88위 아이유(IU) - 마음을 드려요
# 89위 BLACKPINK - You Never Know
# 90위 Dua Lipa(두아 리파) - Don't Start Now
# 91위 기리보이 - 우리서로사랑하지는말자
# 92위 잔나비 - 주저하는 연인들을 위해
# 93위 임영웅 - 이제 나만 믿어요
# 94위 아이유(IU) - Into the I-LAND
# 95위 전상근 - 사랑은 지날수록 더욱 선명하게 남아
# 96위 윤딴딴 - Melody
# 97위 백현(BAEKHYUN) - 나의 시간은
# 98위 조이 (JOY) - 좋은 사람 있으면 소개시켜줘
# 99위 펜타곤 - 데이지
# 100위 Lauv(라우브) - Paris In The Rain
# bugsTOP100.txt 파일에서 읽기 완료
